# %% [markdown]
# <a href="https://colab.research.google.com/github/snehahs03/medical-image-analysis/blob/main/inception_graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# %cd /content/drive/MyDrive/medical-image-analysis
# Out:
# /content/drive/MyDrive/medical-image-analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
history0=np.load('his0_inception.npy',allow_pickle='TRUE').item()
history1=np.load('his1_inception.npy',allow_pickle='TRUE').item()
history2=np.load('his2_inception.npy',allow_pickle='TRUE').item()
history3=np.load('his3_inception.npy',allow_pickle='TRUE').item()

# %%
print(history0.keys())
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc', 'lr'])

# %%
print(history1.keys())
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc', 'lr'])

# %%
print(history2.keys())
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc', 'lr'])

# %%
# Retrieve a list of accuracy results on training and test data
# sets for each training epoch
acc0 = np.array(history0['val_acc'])
acc1 = np.array(history1['val_acc'])
acc2 = np.array(history2['val_acc'])
acc3 = np.array(history3['val_acc'])

# Retrieve a list of list results on training and test data
# sets for each training epoch
loss0 = history0['val_loss']
loss1 = history1['val_loss']
loss2 = history2['val_loss']
loss3 = history3['val_loss']

# Get number of epochs
epochs = range(len(acc0))

plt.figure(figsize=(10,10), dpi=70)


# Plot training and validation accuracy per epoch
plt.plot(epochs, acc0, "-o", label = "training", )
plt.plot(epochs, acc1, "-o", label = "fine_tuning1")
plt.plot(epochs, acc2, "-o", label = "fine_tuning2")
plt.plot(epochs, acc3, "-o", label = "fine_tuning3")
plt.legend(loc="lower right")
plt.title('Accuracy of inception models')
plt.xlabel('epochs')

plt.savefig("inception_accuracy.png")

plt.figure(figsize=(10,10), dpi=70)

# Plot training and validation loss per epoch
plt.plot(epochs, loss0, "-o", label = "training")
plt.plot(epochs, loss1, "-o", label = "fine_tuning1")
plt.plot(epochs, loss2, "-o", label = "fine_tuning2")
plt.plot(epochs, loss3, "-o", label = "fine_tuning3")
plt.legend(loc="upper right")
plt.xlabel('epochs')
plt.title('Loss of inception models')

plt.savefig("inception_loss.png")
